# %%
import matplotlib.pyplot as plt, numpy as np, numpy.random as npr, csv
from mpl_toolkits.mplot3d import Axes3D
from sklearn.manifold import LocallyLinearEmbedding
from tqdm import trange
#%matplotlib notebook
# %matplotlib inline
import torch.nn as nn, timeit, torch, pystan as ps
from time import time
import matplotlib.pyplot as plt
from pylab import plot, show, legend

# %%
sm_refpoints = ps.StanModel(file="/home/postdoc/dsen/Desktop/codes/BNN_dimension_reduction/stan_files/nn_refpoints.stan")
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_6f58d235465c773e740a890b0262cc7f NOW.

# %%
# M = 1000
# X = 10*npr.rand(2,M)
# Y = np.zeros((3,M))
# Y[0] = np.cos(X[0])*np.cos(X[1])
# Y[1] = np.cos(X[0])*np.sin(X[1])
# Y[2] = np.sin(X[0])

# idx = Y[2]>0
# Y = Y[:,idx]
# X = X[:,idx]
# Y += 0.1*npr.rand(*np.shape(Y))
# np.save('Y_sphere.npy', Y)
# np.save('X_sphere.npy', X)

Y = np.load('Y_sphere.npy')
Nobs = np.shape(Y)[1]
print("Nobs =", Nobs)
# Out:
# Nobs = 628

# %% [markdown]
# ### Local linear embedding for reference points:

# %%
n_ref = 100
lat_dim = 2
ref_points = npr.choice(Nobs,n_ref,replace=False)
embedding = LocallyLinearEmbedding(n_components=lat_dim,n_neighbors=10)
Y_embedded = embedding.fit_transform(Y.transpose()).transpose()

# %%
train = np.setdiff1d(np.arange(Nobs), ref_points)
X_ref = X[:,ref_points]
Z_ref = X_embedded[:,ref_points]
X_train = X[:,train]

# %%
n_in = np.shape(Y_embedded)[0]
n_out = np.shape(Y)[0]
n_h = 10

# %%
data = dict(Nobs=Nobs, in_dim=n_in, out_dim=n_out, hidden_dim=n_h, n_ref=n_ref, y=Y_train, y_ref=Y_ref, X_ref=X_ref)

# %% [markdown]
# ### Run Stan:

# %%
start = time()
fit = sm_refpoints.sampling(data=data, thin=1, n_jobs=10, chains=10, init="random", iter=1_000)
print(round((time()-start)/60,2), "minutes to run")
# Out:
# WARNING:pystan:Maximum (flat) parameter count (1000) exceeded: skipping diagnostic tests for n_eff and Rhat.
# To run all diagnostics call pystan.check_hmc_diagnostics(fit)
# WARNING:pystan:13 of 5000 iterations ended with a divergence (0.26 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# WARNING:pystan:4987 of 5000 iterations saturated the maximum tree depth of 10 (99.7 %)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation
# WARNING:pystan:Chain 3: E-BFMI = 0.135
# WARNING:pystan:Chain 7: E-BFMI = 0.0151
# WARNING:pystan:Chain 9: E-BFMI = 0.149
# WARNING:pystan:E-BFMI below 0.2 indicates you may need to reparameterize your model
# 36.07 minutes to run

# %%
trace = fit.extract()
n_samples, n_latent = np.shape(trace['X'])[0], np.shape(trace['X'])[1]

# %% [markdown]
# ### Traceplots of latent variables:

# %%
plt.figure(figsize=(10,8))
idx = npr.choice(n_latent,25).reshape(5,5)

for i in range(5):
    for j in range(5):
        k = 5*i+j
        plt.subplot(5,5,k+1)
        plt.plot(trace['X'][:,idx[i,j],0])
        if i < 4 : plt.xticks(alpha=0)
        if i == 4 : plt.xlabel("MCMC sample", fontsize=12)
        plt.grid(True)
plt.suptitle("Traceplots of some latent variables", fontsize=15, x=0.5,y=0.95)
plt.show()

# %% [markdown]
# ### Loss:

# %%
def L2_loss(X, Z, weights_1, bias_1, weights_2, bias_2) :
    X_pred = np.matmul(np.tanh(np.matmul(Z,weights_1)+bias_1), weights_2) + bias_2
    return np.mean(np.sum((X-X_pred)**2,axis=1))
loss = np.zeros(n_samples)
for i in trange(n_samples) :
    loss[i] = L2_loss(Y_train.transpose(), trace['X'][i], trace['weights_1'][i], 
                      trace['bias_1'][i], trace['weights_2'][i], trace['bias_2'][i])
plt.plot(loss)
plt.title("Loss", fontsize=15)
plt.xlabel("MCMC sample");
# Out:
# 100%|██████████| 5000/5000 [00:00<00:00, 7126.54it/s]

# %% [markdown]
# ### Pairwise distances:

# %%
k_max = 50

pw_dist_matrix = np.zeros((n_latent,n_latent,n_samples))
for k in trange(n_samples) :
    for i in range(k_max) :
        for j in range(k_max) :
            pw_dist_matrix[i,j,k] = np.linalg.norm(trace['X'][k,i]-trace['X'][k,j])
# Out:
# 100%|██████████| 5000/5000 [01:16<00:00, 64.05it/s]

# %%
idx = npr.choice(k_max,10,replace=False)
plt.figure(figsize=(20,15))
for i in range(6):
    for j in range(6):
        if i > j :
            k = 10*i+j+1
            plt.subplot(10,10,k)
            plt.plot(pw_dist_matrix[idx[i],idx[j]])
            if i < 5 : plt.xticks(alpha=0)
            plt.grid(True)
            if i == 5 : plt.xlabel("MCMC sample", fontsize=12)
            if j > 0 : plt.yticks(alpha=0)
            if j == 0 : plt.ylabel("Distance", fontsize=12)
plt.suptitle("Traceplots of some pairwise distances of latent variables for hypersphere", fontsize=14, x=0.31,y=0.83)
# plt.savefig('/home/postdoc/dsen/Desktop/VAE_density/plots/sphere_pwdist_unconstrainedW1_refpoints.pdf', 
#                 dpi=2000, bbox_inches='tight');
# Out:
# Text(0.31, 0.83, 'Traceplots of some pairwise distances of latent variables for hypersphere')
